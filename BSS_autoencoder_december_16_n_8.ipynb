# %% [markdown]
# # Blind source separation with an unsupervised autoencoder
#
# # Daniel Correa Tucunduva

# %% [markdown]
# ## Hyperparameters

# %%
hidden_layer_n = 8
epochs = 100

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

from mne.io import read_raw_eeglab
import numpy as np
from scipy.ndimage import gaussian_filter
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import LearningRateScheduler
from sklearn.decomposition import FastICA
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

print(__doc__)
# Out:
# Using TensorFlow backend.
# Automatically created module for IPython interactive environment

# %% [markdown]
# ## Load real EEG data

# %%
raw_eeg_lab = read_raw_eeglab('./outside_scanner.set')
raw_eeg_lab.load_data()
np_eeg_data = raw_eeg_lab.to_data_frame()
print(np_eeg_data.shape)

n = np_eeg_data.shape[0]
# Out:
# Reading .\outside_scanner.fdt
# Reading 0 ... 124404  =      0.000 ...   497.616 secs...
# <ipython-input-3-5a9b7a979c0e>:1: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw_eeg_lab = read_raw_eeglab('./outside_scanner.set')
# Converting "time" to "<class 'numpy.int64'>"...
# (124405, 64)

# %% [markdown]
# ## ICA

# %%
# ica = FastICA(n_components=3)  # we'll be generous and assume there's 3
# ica.fit(reshape_mixed.T)  # .T because 100000 instances, 100 attributes
# ica_comps = ica.transform(reshape_mixed.T)  # get the components
# ica_weights = np.reshape(ica.components_.T, [10, 10, 3])  # visualize these as images

# %% [markdown]
# ## Autoencoder training

# %%
autoencoder = Sequential()
autoencoder.name = 'autoencoder'
autoencoder.add(Dense(hidden_layer_n, activation='linear', input_shape=[64], kernel_initializer='uniform', use_bias=False, kernel_constraint='nonneg'))
autoencoder.add(Dense(64, activation='linear', kernel_initializer='uniform', use_bias=False, kernel_constraint='nonneg'))

autoencoder.summary()

optimizer = keras.optimizers.SGD(learning_rate=1e-1, momentum=0.0, nesterov=False)

autoencoder.compile(loss='logcosh', optimizer=optimizer)

autoencoder_input = np_eeg_data
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8)                 512
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                512
# =================================================================
# Total params: 1,024
# Trainable params: 1,024
# Non-trainable params: 0
# _________________________________________________________________

# %%
        
def learning_rate_schedule(epoch):
    e = epoch + 1
    if e > 80:
        return 1e-8
    if e > 60:
        return 1e-7
    if e > 40:
        return 1e-6
    if e > 20:
        return 1e-5
    return 1e-4

    
autoencoder_history = autoencoder.fit(autoencoder_input,
                                      autoencoder_input,
                                      batch_size=40,
                                      epochs=epochs,
                                      verbose=1,
                                      callbacks=[
                                      LearningRateScheduler(learning_rate_schedule)
                                      ])
# Out:
# Epoch 1/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 15.4112
# Epoch 2/100
# 124405/124405 [==============================] - 2s 20us/step - loss: 13.2751
# Epoch 3/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 13.1393  - ETA
# Epoch 4/100
# 124405/124405 [==============================] - 2s 20us/step - loss: 12.8555
# Epoch 5/100
# 124405/124405 [==============================] - 2s 20us/step - loss: 12.4051
# Epoch 6/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 12.0346
# Epoch 7/100
# 124405/124405 [==============================] - 2s 20us/step - loss: 11.8067
# Epoch 8/100
# 124405/124405 [==============================] - 2s 20us/step - loss: 11.6403
# Epoch 9/100
# 124405/124405 [==============================] - 2s 20us/step - loss: 11.4965
# Epoch 10/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 11.3673
# Epoch 11/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 11.2597
# Epoch 12/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 11.1659
# Epoch 13/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 11.0785
# Epoch 14/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.9951
# Epoch 15/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.9153
# Epoch 16/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.8374
# Epoch 17/100
# 124405/124405 [==============================] - 3s 27us/step - loss: 10.7564
# Epoch 18/100
# 124405/124405 [==============================] - 3s 25us/step - loss: 10.6711
# Epoch 19/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.5868
# Epoch 20/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.4976
# Epoch 21/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.4440
# Epoch 22/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.4341
# Epoch 23/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.4242
# Epoch 24/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.4147
# Epoch 25/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.4053
# Epoch 26/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.3958
# Epoch 27/100
# 124405/124405 [==============================] - 3s 25us/step - loss: 10.3863
# Epoch 28/100
# 124405/124405 [==============================] - 3s 27us/step - loss: 10.3768
# Epoch 29/100
# 124405/124405 [==============================] - 3s 23us/step - loss: 10.3672
# Epoch 30/100
# 124405/124405 [==============================] - 3s 27us/step - loss: 10.3580
# Epoch 31/100
# 124405/124405 [==============================] - 3s 25us/step - loss: 10.3490
# Epoch 32/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.3399
# Epoch 33/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.3308
# Epoch 34/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.3217
# Epoch 35/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.3125
# Epoch 36/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.3033
# Epoch 37/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.2940
# Epoch 38/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.2846
# Epoch 39/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2751
# Epoch 40/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.2656
# Epoch 41/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2601
# Epoch 42/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2592 0s -
# Epoch 43/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2582
# Epoch 44/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.2572
# Epoch 45/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2562
# Epoch 46/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2553
# Epoch 47/100
# 124405/124405 [==============================] - 3s 23us/step - loss: 10.2543
# Epoch 48/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2533
# Epoch 49/100
# 124405/124405 [==============================] - 3s 23us/step - loss: 10.2524
# Epoch 50/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2514
# Epoch 51/100
# 124405/124405 [==============================] - 3s 23us/step - loss: 10.2504
# Epoch 52/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2495
# Epoch 53/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2485
# Epoch 54/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2475
# Epoch 55/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.2466
# Epoch 56/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2456
# Epoch 57/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2446
# Epoch 58/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2437
# Epoch 59/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2427
# Epoch 60/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2417
# Epoch 61/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2412
# Epoch 62/100
# 124405/124405 [==============================] - 3s 26us/step - loss: 10.2411
# Epoch 63/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2410
# Epoch 64/100
# 124405/124405 [==============================] - 3s 20us/step - loss: 10.2409
# Epoch 65/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2408
# Epoch 66/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2407
# Epoch 67/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2406
# Epoch 68/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2405
# Epoch 69/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2404
# Epoch 70/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2404
# Epoch 71/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2403
# Epoch 72/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2402
# Epoch 73/100
# 124405/124405 [==============================] - 3s 27us/step - loss: 10.2401
# Epoch 74/100
# 124405/124405 [==============================] - 3s 23us/step - loss: 10.2400
# Epoch 75/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2399
# Epoch 76/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2398
# Epoch 77/100
# 124405/124405 [==============================] - 3s 21us/step - loss: 10.2397
# Epoch 78/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2396
# Epoch 79/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2395
# Epoch 80/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2394
# Epoch 81/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2394
# Epoch 82/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2394
# Epoch 83/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2394
# Epoch 84/100
# 124405/124405 [==============================] - 3s 22us/step - loss: 10.2394
# Epoch 85/100
# 124405/124405 [==============================] - 3s 23us/step - loss: 10.2394
# Epoch 86/100
# 124405/124405 [==============================] - 3s 27us/step - loss: 10.2394
# Epoch 87/100
# 124405/124405 [==============================] - 4s 28us/step - loss: 10.2394
# Epoch 88/100
# 124405/124405 [==============================] - 4s 32us/step - loss: 10.2394
# Epoch 89/100
# 124405/124405 [==============================] - 4s 31us/step - loss: 10.2394
# Epoch 90/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2394
# Epoch 91/100
# 124405/124405 [==============================] - 4s 29us/step - loss: 10.2394
# Epoch 92/100
# 124405/124405 [==============================] - 3s 26us/step - loss: 10.2394
# Epoch 93/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2394 0s -
# Epoch 94/100
# 124405/124405 [==============================] - 3s 24us/step - loss: 10.2393
# Epoch 95/100
# 124405/124405 [==============================] - 4s 29us/step - loss: 10.2393
# Epoch 96/100
# 124405/124405 [==============================] - 4s 34us/step - loss: 10.2393
# Epoch 97/100
# 124405/124405 [==============================] - 4s 33us/step - loss: 10.2393
# Epoch 98/100
# 124405/124405 [==============================] - 4s 29us/step - loss: 10.2393
# Epoch 99/100
# 124405/124405 [==============================] - 4s 29us/step - loss: 10.2393
# Epoch 100/100
# 124405/124405 [==============================] - 4s 29us/step - loss: 10.2393

# %%
reconstruction = autoencoder.predict(autoencoder_input)

# %% [markdown]
# ## Original and reconstruction comparison

# %% [markdown]
# ## Recover independent sources from hidden layer

# %%
hidden_layer = Sequential()
hidden_layer.name = 'hidden_layer'
hidden_layer.add(Dense(hidden_layer_n, input_shape=[64], use_bias=False, kernel_constraint='nonneg'))
hidden_layer.summary()

hidden_layer.set_weights(autoencoder.get_weights())

recovered_sources = hidden_layer.predict(autoencoder_input)

names = []
sources = []
for i in range(hidden_layer_n):
    names.append('source_' + str(i))
    sources.append(np.reshape(recovered_sources.T[i], [n, 1]))
# Out:
# Model: "hidden_layer"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 8)                 512
# =================================================================
# Total params: 512
# Trainable params: 512
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## ICA and autoencoder results comparison

# %%
plt.figure(figsize=(15, 15))

models = sources
colors = ['red', 'steelblue', 'orange']

for index, (model, name) in enumerate(zip(models, names), 1):
    plt.subplot(hidden_layer_n * 2 + 2, 1, index * 2)
    plt.title(name)
    for sig, color in zip(model.T, colors):
        plt.plot(sig[0:2000], color=color)
plt.show()
